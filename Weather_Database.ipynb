# %%
# Import the requests library.
# Dependencies 
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import random
from citipy import citipy
from datetime import datetime 
from config import weather_api_key
import requests
import time
from scipy.stats import linregress
# Import the API key.
from config import weather_api_key
#print(weather_api_key)

# %%
# Create list for weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Create basic url for API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create 2000 random latitude and longitude coordinates 
lats = np.random.uniform(-90, 90, size = 2000)
lngs = np.random.uniform(-180, 180, size = 2000)
coordinates = zip(lats, lngs)
coordinates

# Add coordinates to a list 
coordinates_lst = list(coordinates)

# %%
# Use the citipy module to determine city based on latitude and longitude.

#Create list for cities 
cities = []

# Use citipy to find nearest cities using coordinate list
for coordinate in coordinates_lst:
    city = citipy.nearest_city(coordinate[0],coordinate[1])
    city_name = city.city_name
    country_name = city.country_code
    
    # Find unique cities to add to cities list
    if city_name not in cities:
        cities.append(city_name)
    
    # See cities and contries
    # print(f'{city_name}, {country_name}')

# Count amount of unique cities
len(cities)
# Out:
# 774

# %%
# city_url = url + "&q="+"Boston"
# city_weather = requests.get(city_url)
# city_data = city_weather.json()

# %%
# city_data['weather']

# %%
# Loop through city Lists 
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 
    if (i % 50 == 0 and i >= 50):
        set_count += 1 
        record_count = 1 
    
    # Create URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log URL, set, and record numbers for each city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1

# Make an API request for each city 
    try:
       
        # Parse the JSON data
        city_weather = requests.get(city_url).json()

        # Compile needed data
        city_city = city.title()
        city_country = city_weather['sys']['country']
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_hum = city_weather['main']['humidity']
        city_cloud = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_desc = city_weather['weather'][0]['description']
        
# Fill City Data list 
        city_data.append({"City": city_city,
                         "Country": city_country,
                         "Date": city_date,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_hum,
                         "Cloudiness": city_cloud,
                         "Wind Speed": city_wind,
                         "Current Description": city_desc,
                         })
        
    #If an error occurs
    except: 
        print("City not found. Skipping")
        pass

    # Complete Data Retrieval    
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 29 of Set 15 | ushuaia
# Processing Record 30 of Set 15 | rikitea
# Processing Record 31 of Set 15 | clyde river
# Processing Record 32 of Set 15 | jamestown
# Processing Record 33 of Set 15 | la union
# Processing Record 34 of Set 15 | port alfred
# Processing Record 35 of Set 15 | hobart
# Processing Record 36 of Set 15 | saint-philippe
# Processing Record 37 of Set 15 | hithadhoo
# Processing Record 38 of Set 15 | butaritari
# Processing Record 39 of Set 15 | belushya guba
# City not found. Skipping
# Processing Record 40 of Set 15 | khovu-aksy
# Processing Record 41 of Set 15 | dakar
# Processing Record 42 of Set 15 | mont-de-marsan
# Processing Record 43 of Set 15 | bluff
# Processing Record 44 of Set 15 | bonavista
# Processing Record 45 of Set 15 | mataura
# Processing Record 46 of Set 15 | kulu
# Processing Record 47 of Set 15 | igarka
# Processing Record 48 of Set 15 | amderma
# City not found. Skipping
# Processing Record 49 of Set 15 | bredasdorp
# Processing Record 50 of Set 15 | shingu
# Processing Record 51 of Set 15 | victoria
# Processing Record 52 of Set 15 | curup
# Processing Record 53 of Set 15 | port elizabeth
# Processing Record 54 of Set 15 | vaini
# Processing Record 55 of Set 15 | kortkeros
# Processing Record 56 of Set 15 | mar del plata
# Processing Record 57 of Set 15 | lorengau
# Processing Record 58 of Set 15 | lamu
# Processing Record 59 of Set 15 | ambad
# Processing Record 60 of Set 15 | khatanga
# Processing Record 61 of Set 15 | avarua
# Processing Record 62 of Set 15 | saskylakh
# Processing Record 63 of Set 15 | east london
# Processing Record 64 of Set 15 | pontes e lacerda
# Processing Record 65 of Set 15 | lagoa
# Processing Record 66 of Set 15 | bairiki
# Processing Record 67 of Set 15 | viseu
# Processing Record 68 of Set 15 | longyearbyen
# Processing Record 69 of Set 15 | dikson
# Processing Record 70 of Set 15 | port-cartier
# Processing Record 71 of Set 15 | lompoc
# Processing Record 72 of Set 15 | atasu
# Processing Record 73 of Set 15 | isangel
# Processing Record 74 of Set 15 | punta arenas
# Processing Record 75 of Set 15 | chokurdakh
# Processing Record 76 of Set 15 | arraial do cabo
# Processing Record 77 of Set 15 | pisco
# Processing Record 78 of Set 15 | stoyba
# City not found. Skipping
# Processing Record 1 of Set 16 | bengkulu
# Processing Record 2 of Set 16 | severo-kurilsk
# Processing Record 3 of Set 16 | codrington
# Processing Record 4 of Set 16 | busselton
# Processing Record 5 of Set 16 | taolanaro
# City not found. Skipping
# Processing Record 6 of Set 16 | kodinsk
# Processing Record 7 of Set 16 | turayf
# Processing Record 8 of Set 16 | ballina
# Processing Record 9 of Set 16 | hermanus
# Processing Record 10 of Set 16 | sahrak
# City not found. Skipping
# Processing Record 11 of Set 16 | bandarbeyla
# Processing Record 12 of Set 16 | vardo
# Processing Record 13 of Set 16 | korla
# Processing Record 14 of Set 16 | vanimo
# Processing Record 15 of Set 16 | mount isa
# Processing Record 16 of Set 16 | zyryanka
# Processing Record 17 of Set 16 | roros
# Processing Record 18 of Set 16 | tasiilaq
# Processing Record 19 of Set 16 | cape town
# Processing Record 20 of Set 16 | flinders
# Processing Record 21 of Set 16 | tabiauea
# City not found. Skipping
# Processing Record 22 of Set 16 | poum
# Processing Record 23 of Set 16 | kruisfontein
# Processing Record 24 of Set 16 | chapais
# Processing Record 25 of Set 16 | kanniyakumari
# Processing Record 26 of Set 16 | likasi
# Processing Record 27 of Set 16 | belaya gora
# Processing Record 28 of Set 16 | kahului
# Processing Record 29 of Set 16 | illoqqortoormiut
# City not found. Skipping
# Processing Record 30 of Set 16 | barentsburg
# City not found. Skipping
# Processing Record 31 of Set 16 | lebu
# Processing Record 32 of Set 16 | albany
# Processing Record 33 of Set 16 | san luis
# Processing Record 34 of Set 16 | rosarito
# Processing Record 35 of Set 16 | olafsvik
# Processing Record 36 of Set 16 | cockburn town
# Processing Record 37 of Set 16 | bardstown
# Processing Record 38 of Set 16 | griffith
# Processing Record 39 of Set 16 | bela cruz
# Processing Record 40 of Set 16 | sao paulo de olivenca
# Processing Record 41 of Set 16 | mayo
# Processing Record 42 of Set 16 | kununurra
# Processing Record 43 of Set 16 | beloha
# Processing Record 44 of Set 16 | nyakabindi
# Processing Record 45 of Set 16 | nanortalik
# Processing Record 46 of Set 16 | airai
# Processing Record 47 of Set 16 | cherskiy
# Processing Record 48 of Set 16 | lavrentiya
# Processing Record 49 of Set 16 | port lincoln
# Processing Record 50 of Set 16 | ribeira grande
# Processing Record 1 of Set 17 | siena
# Processing Record 2 of Set 17 | beyneu
# Processing Record 3 of Set 17 | juneau
# Processing Record 4 of Set 17 | hualmay
# Processing Record 5 of Set 17 | ngukurr
# City not found. Skipping
# Processing Record 6 of Set 17 | nabire
# Processing Record 7 of Set 17 | kenai
# Processing Record 8 of Set 17 | maniwaki
# Processing Record 9 of Set 17 | nazret
# Processing Record 10 of Set 17 | qaanaaq
# Processing Record 11 of Set 17 | husavik
# Processing Record 12 of Set 17 | nago
# Processing Record 13 of Set 17 | san cristobal
# Processing Record 14 of Set 17 | makung
# City not found. Skipping
# Processing Record 15 of Set 17 | atuona
# Processing Record 16 of Set 17 | castro
# Processing Record 17 of Set 17 | loa janan
# Processing Record 18 of Set 17 | kudahuvadhoo
# Processing Record 19 of Set 17 | acarau
# Processing Record 20 of Set 17 | souillac
# Processing Record 21 of Set 17 | nortelandia
# Processing Record 22 of Set 17 | ostrovnoy
# Processing Record 23 of Set 17 | poddorye
# Processing Record 24 of Set 17 | yellowknife
# Processing Record 25 of Set 17 | mizdah
# Processing Record 26 of Set 17 | cidreira
# Processing Record 27 of Set 17 | kemalpasa
# Processing Record 28 of Set 17 | puerto ayora
# Processing Record 29 of Set 17 | bethel
# Processing Record 30 of Set 17 | zhanaozen
# Processing Record 31 of Set 17 | kapaa
# Processing Record 32 of Set 17 | chuy
# Processing Record 33 of Set 17 | acapulco
# Processing Record 34 of Set 17 | jericho
# Processing Record 35 of Set 17 | new norfolk
# Processing Record 36 of Set 17 | dire dawa
# Processing Record 37 of Set 17 | qaqortoq
# Processing Record 38 of Set 17 | hasaki
# Processing Record 39 of Set 17 | tawang
# Processing Record 40 of Set 17 | hovd
# Processing Record 41 of Set 17 | upernavik
# Processing Record 42 of Set 17 | puri
# Processing Record 43 of Set 17 | champerico
# Processing Record 44 of Set 17 | shantipur
# Processing Record 45 of Set 17 | luderitz
# Processing Record 46 of Set 17 | yaan
# Processing Record 47 of Set 17 | kilgore
# Processing Record 48 of Set 17 | healesville
# Processing Record 49 of Set 17 | saint-pierre
# Processing Record 50 of Set 17 | rio gallegos
# Processing Record 1 of Set 18 | swan river
# Processing Record 2 of Set 18 | ponta do sol
# Processing Record 3 of Set 18 | vila velha
# Processing Record 4 of Set 18 | georgetown
# Processing Record 5 of Set 18 | pangnirtung
# Processing Record 6 of Set 18 | kindu
# Processing Record 7 of Set 18 | aloleng
# Processing Record 8 of Set 18 | nantucket
# Processing Record 9 of Set 18 | padang
# Processing Record 10 of Set 18 | yuanping
# Processing Record 11 of Set 18 | valparaiso
# Processing Record 12 of Set 18 | la ronge
# Processing Record 13 of Set 18 | inhambane
# Processing Record 14 of Set 18 | kizhinga
# Processing Record 15 of Set 18 | iqaluit
# Processing Record 16 of Set 18 | yumen
# Processing Record 17 of Set 18 | mangan
# Processing Record 18 of Set 18 | sao lourenco do oeste
# Processing Record 19 of Set 18 | longhua
# Processing Record 20 of Set 18 | corum
# Processing Record 21 of Set 18 | bowen
# Processing Record 22 of Set 18 | port blair
# Processing Record 23 of Set 18 | hilo
# Processing Record 24 of Set 18 | montigny-les-metz
# Processing Record 25 of Set 18 | yulara
# Processing Record 26 of Set 18 | yarada
# Processing Record 27 of Set 18 | mahebourg
# Processing Record 28 of Set 18 | jundia
# Processing Record 29 of Set 18 | bintulu
# Processing Record 30 of Set 18 | torbay
# Processing Record 31 of Set 18 | flin flon
# Processing Record 32 of Set 18 | mazagao
# Processing Record 33 of Set 18 | margate
# Processing Record 34 of Set 18 | baruun-urt
# Processing Record 35 of Set 18 | kuching
# Processing Record 36 of Set 18 | gazanjyk
# Processing Record 37 of Set 18 | chimbote
# Processing Record 38 of Set 18 | koutiala
# Processing Record 39 of Set 18 | bilma
# Processing Record 40 of Set 18 | lolua
# City not found. Skipping
# Processing Record 41 of Set 18 | kaka
# Processing Record 42 of Set 18 | coihaique
# Processing Record 43 of Set 18 | ilulissat
# Processing Record 44 of Set 18 | kaeo
# Processing Record 45 of Set 18 | lavumisa
# Processing Record 46 of Set 18 | hella
# Processing Record 47 of Set 18 | aguie
# Processing Record 48 of Set 18 | srednekolymsk
# Processing Record 49 of Set 18 | barrow
# Processing Record 50 of Set 18 | sawang daen din
# Processing Record 1 of Set 19 | lusambo
# Processing Record 2 of Set 19 | gat
# Processing Record 3 of Set 19 | waddan
# Processing Record 4 of Set 19 | santa maria del oro
# Processing Record 5 of Set 19 | dunedin
# Processing Record 6 of Set 19 | socorro
# Processing Record 7 of Set 19 | evensk
# Processing Record 8 of Set 19 | corquin
# Processing Record 9 of Set 19 | novyy urengoy
# Processing Record 10 of Set 19 | fandriana
# Processing Record 11 of Set 19 | bathsheba
# Processing Record 12 of Set 19 | hamilton
# Processing Record 13 of Set 19 | miles city
# Processing Record 14 of Set 19 | orotukan
# Processing Record 15 of Set 19 | inuvik
# Processing Record 16 of Set 19 | port augusta
# Processing Record 17 of Set 19 | rungata
# City not found. Skipping
# Processing Record 18 of Set 19 | tyulyachi
# Processing Record 19 of Set 19 | bilibino
# Processing Record 20 of Set 19 | carnarvon
# Processing Record 21 of Set 19 | karratha
# Processing Record 22 of Set 19 | raudeberg
# Processing Record 23 of Set 19 | richards bay
# Processing Record 24 of Set 19 | broome
# Processing Record 25 of Set 19 | marawi
# Processing Record 26 of Set 19 | ihosy
# Processing Record 27 of Set 19 | la palma
# Processing Record 28 of Set 19 | kaitangata
# Processing Record 29 of Set 19 | teberda
# Processing Record 30 of Set 19 | san-pedro
# Processing Record 31 of Set 19 | santa cruz
# Processing Record 32 of Set 19 | norman wells
# Processing Record 33 of Set 19 | bolshaya martynovka
# Processing Record 34 of Set 19 | vazante
# Processing Record 35 of Set 19 | morro bay
# Processing Record 36 of Set 19 | iracoubo
# Processing Record 37 of Set 19 | ponta delgada
# Processing Record 38 of Set 19 | phan thiet
# Processing Record 39 of Set 19 | mrirt
# City not found. Skipping
# Processing Record 40 of Set 19 | tiksi
# Processing Record 41 of Set 19 | gravdal
# Processing Record 42 of Set 19 | sentyabrskiy
# City not found. Skipping
# Processing Record 43 of Set 19 | quatre cocos
# Processing Record 44 of Set 19 | saldanha
# Processing Record 45 of Set 19 | koumac
# Processing Record 46 of Set 19 | pleasanton
# Processing Record 47 of Set 19 | thibodaux
# Processing Record 48 of Set 19 | mitsamiouli
# Processing Record 49 of Set 19 | palabuhanratu
# City not found. Skipping
# Processing Record 50 of Set 19 | tuktoyaktuk
# Processing Record 1 of Set 20 | katsuura
# Processing Record 2 of Set 20 | barber
# Processing Record 3 of Set 20 | luau
# Processing Record 4 of Set 20 | palmer
# Processing Record 5 of Set 20 | vanderhoof
# Processing Record 6 of Set 20 | nakamura
# Processing Record 7 of Set 20 | camana
# Processing Record 8 of Set 20 | jiangkou
# Processing Record 9 of Set 20 | kajaani
# Processing Record 10 of Set 20 | touros
# Processing Record 11 of Set 20 | labuhan
# Processing Record 12 of Set 20 | rio grande
# Processing Record 13 of Set 20 | saint-georges
# Processing Record 14 of Set 20 | petropavlovsk-kamchatskiy
# Processing Record 15 of Set 20 | zeya
# Processing Record 16 of Set 20 | sioux lookout
# Processing Record 17 of Set 20 | jamalpur
# Processing Record 18 of Set 20 | kavieng
# Processing Record 19 of Set 20 | areka
# Processing Record 20 of Set 20 | pevek
# Processing Record 21 of Set 20 | marataizes
# Processing Record 22 of Set 20 | zabol
# Processing Record 23 of Set 20 | iranshahr
# Processing Record 24 of Set 20 | locri
# Processing Record 25 of Set 20 | kloulklubed
# Processing Record 26 of Set 20 | nizhneyansk
# City not found. Skipping
# Processing Record 27 of Set 20 | shymkent
# Processing Record 28 of Set 20 | wageningen
# Processing Record 29 of Set 20 | karaton
# Processing Record 30 of Set 20 | najran
# Processing Record 31 of Set 20 | oksovskiy
# Processing Record 32 of Set 20 | bambous virieux
# Processing Record 33 of Set 20 | khorramshahr
# Processing Record 34 of Set 20 | maragogi
# Processing Record 35 of Set 20 | abashiri
# Processing Record 36 of Set 20 | kavaratti
# Processing Record 37 of Set 20 | nikolskoye
# Processing Record 38 of Set 20 | tricase
# Processing Record 39 of Set 20 | angoram
# Processing Record 40 of Set 20 | abbeville
# Processing Record 41 of Set 20 | mansa
# Processing Record 42 of Set 20 | pecos
# Processing Record 43 of Set 20 | yunjinghong
# City not found. Skipping
# Processing Record 44 of Set 20 | saint george
# Processing Record 45 of Set 20 | klaksvik
# Processing Record 46 of Set 20 | leshukonskoye
# Processing Record 47 of Set 20 | mandera
# Processing Record 48 of Set 20 | san ramon
# Processing Record 49 of Set 20 | yurimaguas
# Processing Record 50 of Set 20 | oranjemund
# Processing Record 1 of Set 21 | sorland
# Processing Record 2 of Set 21 | santa isabel do rio negro
# Processing Record 3 of Set 21 | teguise
# Processing Record 4 of Set 21 | narbonne
# Processing Record 5 of Set 21 | attawapiskat
# City not found. Skipping
# Processing Record 6 of Set 21 | chiali
# City not found. Skipping
# Processing Record 7 of Set 21 | tecoanapa
# Processing Record 8 of Set 21 | buala
# Processing Record 9 of Set 21 | umzimvubu
# City not found. Skipping
# Processing Record 10 of Set 21 | skibbereen
# Processing Record 11 of Set 21 | hirado
# Processing Record 12 of Set 21 | veraval
# Processing Record 13 of Set 21 | aklavik
# Processing Record 14 of Set 21 | muros
# Processing Record 15 of Set 21 | verkhoyansk
# Processing Record 16 of Set 21 | rawson
# Processing Record 17 of Set 21 | sitka
# Processing Record 18 of Set 21 | sulangan
# Processing Record 19 of Set 21 | nemuro
# Processing Record 20 of Set 21 | colac
# Processing Record 21 of Set 21 | mackenzie
# Processing Record 22 of Set 21 | santiago del estero
# Processing Record 23 of Set 21 | sorong
# Processing Record 24 of Set 21 | yatou
# Processing Record 25 of Set 21 | kochubey
# Processing Record 26 of Set 21 | yendi
# Processing Record 27 of Set 21 | hofn
# Processing Record 28 of Set 21 | spasskoye
# Processing Record 29 of Set 21 | doctor pedro p. pena
# City not found. Skipping
# Processing Record 30 of Set 21 | keti bandar
# Processing Record 31 of Set 21 | samusu
# City not found. Skipping
# Processing Record 32 of Set 21 | esperance
# Processing Record 33 of Set 21 | takhtamygda
# Processing Record 34 of Set 21 | straumen
# Processing Record 35 of Set 21 | bollnas
# Processing Record 36 of Set 21 | vrangel
# Processing Record 37 of Set 21 | klyuchi
# Processing Record 38 of Set 21 | urumqi
# Processing Record 39 of Set 21 | mandalgovi
# Processing Record 40 of Set 21 | ust-tsilma
# Processing Record 41 of Set 21 | coquimbo
# Processing Record 42 of Set 21 | antalaha
# Processing Record 43 of Set 21 | alyangula
# Processing Record 44 of Set 21 | yerbogachen
# Processing Record 45 of Set 21 | ancud
# Processing Record 46 of Set 21 | fortuna
# Processing Record 47 of Set 21 | atambua
# Processing Record 48 of Set 21 | oudtshoorn
# Processing Record 49 of Set 21 | lodja
# Processing Record 50 of Set 21 | provideniya
# Processing Record 1 of Set 22 | san jose
# Processing Record 2 of Set 22 | angoche
# Processing Record 3 of Set 22 | qiongshan
# Processing Record 4 of Set 22 | sao miguel do araguaia
# Processing Record 5 of Set 22 | antofagasta
# Processing Record 6 of Set 22 | ternate
# Processing Record 7 of Set 22 | ust-koksa
# Processing Record 8 of Set 22 | saleaula
# City not found. Skipping
# Processing Record 9 of Set 22 | tazovskiy
# Processing Record 10 of Set 22 | sangar
# Processing Record 11 of Set 22 | bolungarvik
# City not found. Skipping
# Processing Record 12 of Set 22 | morehead
# Processing Record 13 of Set 22 | cabo san lucas
# Processing Record 14 of Set 22 | dickinson
# Processing Record 15 of Set 22 | sao raimundo nonato
# Processing Record 16 of Set 22 | san patricio
# Processing Record 17 of Set 22 | los llanos de aridane
# Processing Record 18 of Set 22 | aripuana
# Processing Record 19 of Set 22 | narsaq
# Processing Record 20 of Set 22 | havre-saint-pierre
# Processing Record 21 of Set 22 | satitoa
# City not found. Skipping
# Processing Record 22 of Set 22 | kadyy
# Processing Record 23 of Set 22 | kuytun
# Processing Record 24 of Set 22 | bhag
# Processing Record 25 of Set 22 | kadoma
# Processing Record 26 of Set 22 | contai
# Processing Record 27 of Set 22 | te anau
# Processing Record 28 of Set 22 | tsihombe
# City not found. Skipping
# Processing Record 29 of Set 22 | uray
# Processing Record 30 of Set 22 | meyungs
# City not found. Skipping
# Processing Record 31 of Set 22 | kieta
# Processing Record 32 of Set 22 | riyadh
# Processing Record 33 of Set 22 | yar-sale
# Processing Record 34 of Set 22 | micheweni
# Processing Record 35 of Set 22 | ingham
# Processing Record 36 of Set 22 | mehamn
# Processing Record 37 of Set 22 | awjilah
# Processing Record 38 of Set 22 | oga
# Processing Record 39 of Set 22 | kodiak
# Processing Record 40 of Set 22 | uramita
# Processing Record 41 of Set 22 | fairbanks
# Processing Record 42 of Set 22 | sao filipe
# Processing Record 43 of Set 22 | pereslavl-zalesskiy
# Processing Record 44 of Set 22 | ghauspur
# Processing Record 45 of Set 22 | nanzhou
# Processing Record 46 of Set 22 | geraldton
# Processing Record 47 of Set 22 | henties bay
# Processing Record 48 of Set 22 | villazon
# Processing Record 49 of Set 22 | stryn
# Processing Record 50 of Set 22 | thompson
# Processing Record 1 of Set 23 | payson
# Processing Record 2 of Set 23 | cherbourg
# Processing Record 3 of Set 23 | crotone
# Processing Record 4 of Set 23 | brigantine
# Processing Record 5 of Set 23 | soe
# Processing Record 6 of Set 23 | grand gaube
# Processing Record 7 of Set 23 | ballarat
# Processing Record 8 of Set 23 | alofi
# Processing Record 9 of Set 23 | faya
# Processing Record 10 of Set 23 | guerrero negro
# Processing Record 11 of Set 23 | hervey bay
# Processing Record 12 of Set 23 | zhigansk
# Processing Record 13 of Set 23 | yuzhno-yeniseyskiy
# City not found. Skipping
# Processing Record 14 of Set 23 | blackfoot
# Processing Record 15 of Set 23 | sur
# Processing Record 16 of Set 23 | tucupita
# Processing Record 17 of Set 23 | berbera
# Processing Record 18 of Set 23 | meadow lake
# Processing Record 19 of Set 23 | potosi
# Processing Record 20 of Set 23 | kattivakkam
# Processing Record 21 of Set 23 | prince rupert
# Processing Record 22 of Set 23 | rantepao
# Processing Record 23 of Set 23 | yevsino
# Processing Record 24 of Set 23 | matara
# Processing Record 25 of Set 23 | omboue
# Processing Record 26 of Set 23 | bonthe
# Processing Record 27 of Set 23 | marzuq
# Processing Record 28 of Set 23 | paraiso
# Processing Record 29 of Set 23 | barguzin
# Processing Record 30 of Set 23 | pemangkat
# Processing Record 31 of Set 23 | islamkot
# Processing Record 32 of Set 23 | lebanon
# Processing Record 33 of Set 23 | cortes
# Processing Record 34 of Set 23 | mys shmidta
# City not found. Skipping
# Processing Record 35 of Set 23 | nakano
# Processing Record 36 of Set 23 | coreau
# Processing Record 37 of Set 23 | grand river south east
# City not found. Skipping
# Processing Record 38 of Set 23 | turtkul
# City not found. Skipping
# Processing Record 39 of Set 23 | talara
# Processing Record 40 of Set 23 | krasnousolskiy
# City not found. Skipping
# Processing Record 41 of Set 23 | udalguri
# Processing Record 42 of Set 23 | karamay
# City not found. Skipping
# Processing Record 43 of Set 23 | anar darreh
# City not found. Skipping
# Processing Record 44 of Set 23 | karwar
# Processing Record 45 of Set 23 | fuyu
# Processing Record 46 of Set 23 | coria
# Processing Record 47 of Set 23 | santana do mundau
# Processing Record 48 of Set 23 | maihar
# Processing Record 49 of Set 23 | tunduma
# Processing Record 50 of Set 23 | mattawa
# Processing Record 1 of Set 24 | warqla
# City not found. Skipping
# Processing Record 2 of Set 24 | shangrao
# Processing Record 3 of Set 24 | san carlos de bariloche
# Processing Record 4 of Set 24 | lata
# Processing Record 5 of Set 24 | madang
# Processing Record 6 of Set 24 | san joaquin
# Processing Record 7 of Set 24 | salalah
# Processing Record 8 of Set 24 | bolshiye uki
# City not found. Skipping
# Processing Record 9 of Set 24 | san vicente
# Processing Record 10 of Set 24 | vila franca do campo
# Processing Record 11 of Set 24 | penzance
# Processing Record 12 of Set 24 | kasongo-lunda
# Processing Record 13 of Set 24 | basco
# Processing Record 14 of Set 24 | narok
# Processing Record 15 of Set 24 | mabaruma
# Processing Record 16 of Set 24 | kirakira
# Processing Record 17 of Set 24 | zaysan
# Processing Record 18 of Set 24 | walvis bay
# Processing Record 19 of Set 24 | oktyabrskoye
# Processing Record 20 of Set 24 | bagan
# Processing Record 21 of Set 24 | lasa
# Processing Record 22 of Set 24 | ngunguru
# Processing Record 23 of Set 24 | rapid valley
# Processing Record 24 of Set 24 | kadykchan
# City not found. Skipping
# Processing Record 25 of Set 24 | manta
# Processing Record 26 of Set 24 | port macquarie
# Processing Record 27 of Set 24 | saint-paul
# Processing Record 28 of Set 24 | ixtapa
# Processing Record 29 of Set 24 | dingle
# Processing Record 30 of Set 24 | tessalit
# Processing Record 31 of Set 24 | ahipara
# Processing Record 32 of Set 24 | kailua
# Processing Record 33 of Set 24 | puerto madryn
# Processing Record 34 of Set 24 | mundo nuevo
# Processing Record 35 of Set 24 | mbanza-ngungu
# Processing Record 36 of Set 24 | port hedland
# Processing Record 37 of Set 24 | sistranda
# Processing Record 38 of Set 24 | reconquista
# Processing Record 39 of Set 24 | panaba
# Processing Record 40 of Set 24 | marcona
# City not found. Skipping
# Processing Record 41 of Set 24 | grenada
# Processing Record 42 of Set 24 | campbell river
# Processing Record 43 of Set 24 | puerto berrio
# Processing Record 44 of Set 24 | maningrida
# Processing Record 45 of Set 24 | san jorge
# Processing Record 46 of Set 24 | virginia beach
# Processing Record 47 of Set 24 | yarmouth
# Processing Record 48 of Set 24 | middlebury
# Processing Record 49 of Set 24 | karaul
# City not found. Skipping
# Processing Record 50 of Set 24 | bantou
# Processing Record 1 of Set 25 | san policarpo
# Processing Record 2 of Set 25 | huilong
# Processing Record 3 of Set 25 | luanda
# Processing Record 4 of Set 25 | saint-nazaire
# Processing Record 5 of Set 25 | sinnamary
# Processing Record 6 of Set 25 | loncoche
# Processing Record 7 of Set 25 | paita
# Processing Record 8 of Set 25 | samarai
# Processing Record 9 of Set 25 | santa rosa
# Processing Record 10 of Set 25 | afmadu
# City not found. Skipping
# Processing Record 11 of Set 25 | goderich
# Processing Record 12 of Set 25 | pskov
# Processing Record 13 of Set 25 | puerto colombia
# Processing Record 14 of Set 25 | rocha
# Processing Record 15 of Set 25 | kurduvadi
# Processing Record 16 of Set 25 | halifax
# Processing Record 17 of Set 25 | pankrushikha
# Processing Record 18 of Set 25 | antsohihy
# Processing Record 19 of Set 25 | corrente
# Processing Record 20 of Set 25 | eldikan
# City not found. Skipping
# Processing Record 21 of Set 25 | moose factory
# Processing Record 22 of Set 25 | krasnoselkup
# Processing Record 23 of Set 25 | tucuma
# Processing Record 24 of Set 25 | mantua
# Processing Record 25 of Set 25 | high level
# Processing Record 26 of Set 25 | bria
# Processing Record 27 of Set 25 | premia de mar
# Processing Record 28 of Set 25 | grand centre
# City not found. Skipping
# Processing Record 29 of Set 25 | caravelas
# Processing Record 30 of Set 25 | sao joao da barra
# Processing Record 31 of Set 25 | karamea
# City not found. Skipping
# Processing Record 32 of Set 25 | egvekinot
# Processing Record 33 of Set 25 | truro
# Processing Record 34 of Set 25 | constitucion
# Processing Record 35 of Set 25 | marsh harbour
# Processing Record 36 of Set 25 | fuerte olimpo
# Processing Record 37 of Set 25 | tupik
# Processing Record 38 of Set 25 | gorno-chuyskiy
# City not found. Skipping
# Processing Record 39 of Set 25 | bayan
# Processing Record 40 of Set 25 | havoysund
# Processing Record 41 of Set 25 | vaitupu
# City not found. Skipping
# Processing Record 42 of Set 25 | sinegorskiy
# Processing Record 43 of Set 25 | chicama
# Processing Record 44 of Set 25 | nome
# Processing Record 45 of Set 25 | acajutla
# Processing Record 46 of Set 25 | brae
# Processing Record 47 of Set 25 | mgandu
# Processing Record 48 of Set 25 | dmitriyevka
# Processing Record 49 of Set 25 | gushikawa
# Processing Record 50 of Set 25 | broken hill
# Processing Record 1 of Set 26 | nakatsugawa
# Processing Record 2 of Set 26 | gobabis
# Processing Record 3 of Set 26 | la esperanza
# Processing Record 4 of Set 26 | borovoy
# Processing Record 5 of Set 26 | roald
# Processing Record 6 of Set 26 | alice town
# Processing Record 7 of Set 26 | galan
# Processing Record 8 of Set 26 | escarcega
# Processing Record 9 of Set 26 | umm lajj
# Processing Record 10 of Set 26 | sambava
# Processing Record 11 of Set 26 | praia
# Processing Record 12 of Set 26 | nhulunbuy
# Processing Record 13 of Set 26 | praia da vitoria
# Processing Record 14 of Set 26 | bumbuna
# Processing Record 15 of Set 26 | saint anthony
# Processing Record 16 of Set 26 | byron bay
# Processing Record 17 of Set 26 | jining
# Processing Record 18 of Set 26 | nouadhibou
# Processing Record 19 of Set 26 | tawkar
# City not found. Skipping
# Processing Record 20 of Set 26 | tumannyy
# City not found. Skipping
# Processing Record 21 of Set 26 | ciras
# City not found. Skipping
# Processing Record 22 of Set 26 | olonets
# Processing Record 23 of Set 26 | tuatapere
# Processing Record 24 of Set 26 | vilcun
# Processing Record 25 of Set 26 | wattegama
# Processing Record 26 of Set 26 | ellisras
# Processing Record 27 of Set 26 | marsa matruh
# Processing Record 28 of Set 26 | ambulu
# Processing Record 29 of Set 26 | setermoen
# Processing Record 30 of Set 26 | ridgecrest
# Processing Record 31 of Set 26 | verkhnyaya inta
# Processing Record 32 of Set 26 | nokaneng
# Processing Record 33 of Set 26 | seoul
# Processing Record 34 of Set 26 | brokopondo
# Processing Record 35 of Set 26 | rawannawi
# City not found. Skipping
# Processing Record 36 of Set 26 | faanui
# Processing Record 37 of Set 26 | buchanan
# Processing Record 38 of Set 26 | chum phae
# Processing Record 39 of Set 26 | smithers
# Processing Record 40 of Set 26 | dryden
# Processing Record 41 of Set 26 | qasigiannguit
# Processing Record 42 of Set 26 | tsienyane
# City not found. Skipping
# Processing Record 43 of Set 26 | clonakilty
# Processing Record 44 of Set 26 | kati
# Processing Record 45 of Set 26 | santa vitoria do palmar
# Processing Record 46 of Set 26 | sokoni
# Processing Record 47 of Set 26 | solsvik
# City not found. Skipping
# Processing Record 48 of Set 26 | predivinsk
# Processing Record 49 of Set 26 | udachnyy
# Processing Record 50 of Set 26 | nador
# Processing Record 1 of Set 27 | bremerton
# Processing Record 2 of Set 27 | kawana waters
# City not found. Skipping
# Processing Record 3 of Set 27 | makakilo city
# Processing Record 4 of Set 27 | alcudia
# Processing Record 5 of Set 27 | tautira
# Processing Record 6 of Set 27 | jalu
# Processing Record 7 of Set 27 | tankara
# Processing Record 8 of Set 27 | hazorasp
# Processing Record 9 of Set 27 | general roca
# Processing Record 10 of Set 27 | camapua
# Processing Record 11 of Set 27 | ozgon
# City not found. Skipping
# Processing Record 12 of Set 27 | svidnik
# Processing Record 13 of Set 27 | kiama
# Processing Record 14 of Set 27 | mareeba
# Processing Record 15 of Set 27 | kondopoga
# Processing Record 16 of Set 27 | kumluca
# Processing Record 17 of Set 27 | aviles
# Processing Record 18 of Set 27 | catabola
# Processing Record 19 of Set 27 | noumea
# Processing Record 20 of Set 27 | dandong
# Processing Record 21 of Set 27 | vanavara
# Processing Record 22 of Set 27 | khormuj
# City not found. Skipping
# Processing Record 23 of Set 27 | saint-augustin
# Processing Record 24 of Set 27 | salcedo
# Processing Record 25 of Set 27 | zomin
# Processing Record 26 of Set 27 | saint-joseph
# Processing Record 27 of Set 27 | galle
# Processing Record 28 of Set 27 | pirajui
# Processing Record 29 of Set 27 | singaparna
# Processing Record 30 of Set 27 | chimoio
# Processing Record 31 of Set 27 | hirara
# Processing Record 32 of Set 27 | yangambi
# Processing Record 33 of Set 27 | longfeng
# Processing Record 34 of Set 27 | guayaramerin
# Processing Record 35 of Set 27 | port keats
# Processing Record 36 of Set 27 | dois vizinhos
# Processing Record 37 of Set 27 | lilongwe
# Processing Record 38 of Set 27 | cacu
# Processing Record 39 of Set 27 | radenci
# Processing Record 40 of Set 27 | camacha
# Processing Record 41 of Set 27 | suntar
# Processing Record 42 of Set 27 | shimoda
# Processing Record 43 of Set 27 | benguela
# Processing Record 44 of Set 27 | hambantota
# Processing Record 45 of Set 27 | rampura
# Processing Record 46 of Set 27 | maarianhamina
# Processing Record 47 of Set 27 | ilebo
# Processing Record 48 of Set 27 | leningradskiy
# Processing Record 49 of Set 27 | perelyub
# Processing Record 50 of Set 27 | makinsk
# Processing Record 1 of Set 28 | wamba
# Processing Record 2 of Set 28 | upington
# Processing Record 3 of Set 28 | kota belud
# Processing Record 4 of Set 28 | parchim
# Processing Record 5 of Set 28 | elko
# Processing Record 6 of Set 28 | sao joao do paraiso
# Processing Record 7 of Set 28 | kitimat
# Processing Record 8 of Set 28 | harper
# Processing Record 9 of Set 28 | kuito
# Processing Record 10 of Set 28 | tabou
# Processing Record 11 of Set 28 | tura
# Processing Record 12 of Set 28 | peleduy
# Processing Record 13 of Set 28 | arman
# Processing Record 14 of Set 28 | maniitsoq
# Processing Record 15 of Set 28 | ypsonas
# Processing Record 16 of Set 28 | upata
# Processing Record 17 of Set 28 | manica
# Processing Record 18 of Set 28 | ath
# Processing Record 19 of Set 28 | bac lieu
# Processing Record 20 of Set 28 | malinovskiy
# Processing Record 21 of Set 28 | altay
# Processing Record 22 of Set 28 | necochea
# Processing Record 23 of Set 28 | dudinka
# Processing Record 24 of Set 28 | mola di bari
# Processing Record 25 of Set 28 | corrales
# Processing Record 26 of Set 28 | churapcha
# Processing Record 27 of Set 28 | pizarro
# Processing Record 28 of Set 28 | kakching
# Processing Record 29 of Set 28 | manggar
# Processing Record 30 of Set 28 | joao pessoa
# Processing Record 31 of Set 28 | campoverde
# Processing Record 32 of Set 28 | dauphin
# Processing Record 33 of Set 28 | myitkyina
# Processing Record 34 of Set 28 | kovur
# Processing Record 35 of Set 28 | olginskaya
# Processing Record 36 of Set 28 | barabinsk
# Processing Record 37 of Set 28 | chernyshkovskiy
# Processing Record 38 of Set 28 | atbasar
# Processing Record 39 of Set 28 | santa maria
# Processing Record 40 of Set 28 | naze
# Processing Record 41 of Set 28 | gillette
# Processing Record 42 of Set 28 | labutta
# City not found. Skipping
# Processing Record 43 of Set 28 | kibala
# Processing Record 44 of Set 28 | springbok
# Processing Record 45 of Set 28 | santa catarina de tepehuanes
# Processing Record 46 of Set 28 | boa vista
# Processing Record 47 of Set 28 | sumbe
# Processing Record 48 of Set 28 | fort nelson
# Processing Record 49 of Set 28 | ketchikan
# Processing Record 50 of Set 28 | ahuatempan
# Processing Record 1 of Set 29 | chaman
# Processing Record 2 of Set 29 | samagaltay
# Processing Record 3 of Set 29 | nicoya
# Processing Record 4 of Set 29 | revelstoke
# Processing Record 5 of Set 29 | college
# Processing Record 6 of Set 29 | asau
# Processing Record 7 of Set 29 | beringovskiy
# Processing Record 8 of Set 29 | itoman
# Processing Record 9 of Set 29 | bulgan
# Processing Record 10 of Set 29 | waingapu
# Processing Record 11 of Set 29 | tuy hoa
# Processing Record 12 of Set 29 | haines junction
# Processing Record 13 of Set 29 | rancho palos verdes
# Processing Record 14 of Set 29 | bethanien
# Processing Record 15 of Set 29 | gigmoto
# Processing Record 16 of Set 29 | sechura
# Processing Record 17 of Set 29 | katangli
# Processing Record 18 of Set 29 | ronnede
# Processing Record 19 of Set 29 | bukama
# Processing Record 20 of Set 29 | yefira
# City not found. Skipping
# Processing Record 21 of Set 29 | andros town
# Processing Record 22 of Set 29 | kutum
# Processing Record 23 of Set 29 | matias barbosa
# Processing Record 24 of Set 29 | kimbe
# Processing Record 25 of Set 29 | gornyy
# Processing Record 26 of Set 29 | port shepstone
# Processing Record 27 of Set 29 | shenjiamen
# Processing Record 28 of Set 29 | bon accord
# Processing Record 29 of Set 29 | touba
# Processing Record 30 of Set 29 | tokzar
# City not found. Skipping
# Processing Record 31 of Set 29 | guozhen
# Processing Record 32 of Set 29 | sribne
# Processing Record 33 of Set 29 | vestmanna
# Processing Record 34 of Set 29 | toftir
# City not found. Skipping
# Processing Record 35 of Set 29 | miyakonojo
# Processing Record 36 of Set 29 | niquelandia
# Processing Record 37 of Set 29 | dobson
# Processing Record 38 of Set 29 | altamira
# Processing Record 39 of Set 29 | borlange
# City not found. Skipping
# Processing Record 40 of Set 29 | pandelys
# City not found. Skipping
# Processing Record 41 of Set 29 | inverell
# Processing Record 42 of Set 29 | carutapera
# Processing Record 43 of Set 29 | mogadishu
# Processing Record 44 of Set 29 | salta
# Processing Record 45 of Set 29 | namibe
# Processing Record 46 of Set 29 | leua
# Processing Record 47 of Set 29 | severodvinsk
# Processing Record 48 of Set 29 | skovorodino
# Processing Record 49 of Set 29 | katherine
# Processing Record 50 of Set 29 | manokwari
# Processing Record 1 of Set 30 | cananeia
# Processing Record 2 of Set 30 | xining
# Processing Record 3 of Set 30 | bhopal
# Processing Record 4 of Set 30 | terra santa
# Processing Record 5 of Set 30 | nyurba
# Processing Record 6 of Set 30 | half moon bay
# Processing Record 7 of Set 30 | axim
# Processing Record 8 of Set 30 | bullhead city
# Processing Record 9 of Set 30 | galiwinku
# City not found. Skipping
# Processing Record 10 of Set 30 | high rock
# Processing Record 11 of Set 30 | lhokseumawe
# Processing Record 12 of Set 30 | kyzyl
# Processing Record 13 of Set 30 | cardston
# Processing Record 14 of Set 30 | kamyshin
# Processing Record 15 of Set 30 | carballo
# Processing Record 16 of Set 30 | lang son
# Processing Record 17 of Set 30 | ilo
# Processing Record 18 of Set 30 | songjianghe
# Processing Record 19 of Set 30 | paoua
# Processing Record 20 of Set 30 | gorom-gorom
# Processing Record 21 of Set 30 | san quintin
# Processing Record 22 of Set 30 | ramasukha
# City not found. Skipping
# Processing Record 23 of Set 30 | chumikan
# Processing Record 24 of Set 30 | deer lake
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 673

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                 City Country                 Date      Lat       Lng  \
# 0           Katsuura      JP  2021-11-27 16:54:15  35.1333  140.3000
# 1         Priiskovyy      RU  2021-11-27 16:54:16  51.9333  116.6333
# 2           Filingue      NE  2021-11-27 16:54:16  14.3521    3.3168
# 3          Busselton      AU  2021-11-27 16:54:16 -33.6500  115.3333
# 4    Bambous Virieux      MU  2021-11-27 16:54:17 -20.3428   57.7575
# ..               ...     ...                  ...      ...       ...
# 668       Rustenburg      ZA  2021-11-27 16:58:41 -25.6676   27.2421
# 669        Abu Dhabi      AE  2021-11-27 16:57:15  24.4667   54.3667
# 670        Hay River      CA  2021-11-27 16:58:42  60.8156 -115.7999
# 671          Cabinda      AO  2021-11-27 16:58:42  -5.5500   12.2000
# 672     Staryy Nadym      RU  2021-11-27 16:58:43  65.6118   72.6842
#
#      Max Temp  Humidity  Cloudiness  Wind Speed Current Description
# 0       46.51        55          27        9.60    scattered clouds
# 1        9.91        96         100        0.78     overcast clouds
# 2       90.95        10          82        7.85       broken clouds
# 3       64.87        67           0        6.38           clear sky
# 4       79.05        73          20        3.44          few clouds
# ..        ...       ...         ...         ...                 ...
# 668     72.86        48          70       12.75       broken clouds
# 669     80.71        69           0        8.05           clear sky
# 670     -7.62        84          40        3.44    scattered clouds
# 671     77.14        94          75        5.75       broken clouds
# 672      7.45        96         100        6.62     overcast clouds
#
# [673 rows x 10 columns]

# %%
# new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp","Humidity", "Cloudiness", "Wind Speed", "Current Description"]
# city_data_df = city_data_df[new_column_order]
# city_data_df

# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
